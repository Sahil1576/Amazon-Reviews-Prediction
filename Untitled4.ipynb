# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Final_sample_dataset.csv')

# %%
df
# Out:
#                                                      Text    lables
# 0       This seems a little more wholesome than some o...   Neutral
# 1       The flavors are good.  However, I do not see a...   Neutral
# 2       This is the same stuff you can buy at the big ...   Neutral
# 3       we're used to spicy foods down here in south t...   Neutral
# 4       Watch your prices with this.  While the assort...   Neutral
# ...                                                   ...       ...
# 109767  my first experience with this oil was at what ...  Positive
# 109768  After trying MANY evoo's, we're convinced this...  Positive
# 109769  Love this olive oil.  It has a great flavor an...  Positive
# 109770  My daughter has craved this since her trip to ...  Positive
# 109771  I drink mainly black tea, but there are some g...  Positive
#
# [109772 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=25000, ngram_range=(1,2))

# %%
tfidf_matrix = tfidf.fit_transform(df['Text'])

# %%
tfidf_matrix.shape
# Out:
# (109772, 25000)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
X = tfidf_matrix.copy()
y = df['lables']

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 10541889 stored elements and shape (109772, 25000)>

# %%
y
# Out:
# 0          Neutral
# 1          Neutral
# 2          Neutral
# 3          Neutral
# 4          Neutral
#             ...
# 109767    Positive
# 109768    Positive
# 109769    Positive
# 109770    Positive
# 109771    Positive
# Name: lables, Length: 109772, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (73547, 25000)

# %%
y_train.value_counts()
# Out:
# lables
# Positive    26897
# Negative    26647
# Neutral     20003
# Name: count, dtype: int64

# %%
from sklearn.svm import LinearSVC

# %%
model = LinearSVC(C=0.5, class_weight='balanced', loss='hinge', max_iter=2000,
          random_state=42)
model.fit(X_train, y_train)
# Out:
# LinearSVC(C=0.5, class_weight='balanced', loss='hinge', max_iter=2000,
#           random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7581780538302277

# %%
y_pred_train = model.predict(X_train)
accuracy_score(y_train, y_pred_train)
# Out:
# 0.8368798183474513

# %%
pd.DataFrame(classification_report(y_test, y_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score       support
# Negative       0.767467  0.787239  0.777227  13353.000000
# Neutral        0.631958  0.584604  0.607359   9769.000000
# Positive       0.833296  0.857971  0.845454  13103.000000
# accuracy       0.758178  0.758178  0.758178      0.758178
# macro avg      0.744240  0.743272  0.743347  36225.000000
# weighted avg   0.754735  0.758178  0.756096  36225.000000

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
params_grid = {
    'C':[0.01,0.1,0.5,1,2,5,10,20],
    'loss':['hinge','squared_hinge'],
    'class_weight':[None, 'balanced',
                   {0:1,1:2, 2:1},
                   {0:1,1:3, 2:1},
                   {0:1,1:3, 2:2}
                   ],
    'max_iter':[2000,5000]
}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(
    estimator=model, 
    param_grid=params_grid, 
    cv=3, 
    scoring='accuracy', 
    n_jobs=-1
)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=LinearSVC(class_weight='balanced', random_state=42),
#              n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 0.5, 1, 2, 5, 10, 20],
#                          'class_weight': [None, 'balanced', {0: 1, 1: 2, 2: 1},
#                                           {0: 1, 1: 3, 2: 1},
#                                           {0: 1, 1: 3, 2: 2}],
#                          'loss': ['hinge', 'squared_hinge'],
#                          'max_iter': [2000, 5000]},
#              scoring='accuracy')

# %%
import joblib

# %%
joblib.dump(tfidf, 'TF-IDF.pkl')
joblib.dump(model, 'LinearSVC.pkl')
# Out:
# ['LinearSVC.pkl']

# %%
joblib.dump(tfidf, 'TF-IDF.pkl')
# Out:
# ['TF-IDF.pkl']

# %%
df.sample('1000_sample_dataset.csv')
# Out:
#                                                      Text    lables
# 0       This seems a little more wholesome than some o...   Neutral
# 1       The flavors are good.  However, I do not see a...   Neutral
# 2       This is the same stuff you can buy at the big ...   Neutral
# 3       we're used to spicy foods down here in south t...   Neutral
# 4       Watch your prices with this.  While the assort...   Neutral
# ...                                                   ...       ...
# 109767  my first experience with this oil was at what ...  Positive
# 109768  After trying MANY evoo's, we're convinced this...  Positive
# 109769  Love this olive oil.  It has a great flavor an...  Positive
# 109770  My daughter has craved this since her trip to ...  Positive
# 109771  I drink mainly black tea, but there are some g...  Positive
#
# [109772 rows x 2 columns]
